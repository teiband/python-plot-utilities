# %%
import sys
sys.dont_write_bytecode = True
sys.path.append('../')

# %%
import numpy as np
import pandas as pd
import sklearn.datasets
import matplotlib.pyplot as plt

# %%
import plot_utils as pu

# %%
# %matplotlib inline

# %% [markdown]
# ### Correlation matrix

# %% [markdown]
# The Boston house price dataset. Each column of `X` is a factor that potentially influences the sale price of a house:

# %%
data = sklearn.datasets.load_boston()
X = pd.DataFrame(data.data,columns=data.feature_names)
pu.plot_correlation(X, scatter_plots=True, ncols_scatter_plots=4);

# %% [markdown]
# The breast cancer data set. Each column of `X` is a characteristic of a tumor:

# %%
data = sklearn.datasets.load_breast_cancer()
X = pd.DataFrame(data.data,columns=data.feature_names)
pu.plot_correlation(X, rot=90, scatter_plots=True, thres=0.9, ncols_scatter_plots=4);
