# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import plot_utils as pu

# %%
# %matplotlib inline

# %% [markdown]
# ### Correlation matrix

# %%
data = pd.read_csv('./datasets/iris.csv')
pu.plot_correlation(data, scatter_plots=True);
